# %%
import requests
import pandas as pd
import json
import pdb

# %% [markdown]
# # Working with the elephant-api

# %%
url = 'https://elephant-api.herokuapp.com/elephants'

# %%
url
# Out:
# 'https://elephant-api.herokuapp.com/elephants'

# %%
req = requests.get(url)

# %%
type(req)
# Out:
# requests.models.Response

# %%
req.json()
# Out:
# [{'_id': '5cf1d0db3cfbe0fcbb6c4c93',
#   'index': 1,
#   'name': 'Abul-Abbas',
#   'affiliation': 'Charlemagne',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '810',
#   'wikilink': 'https://en.wikipedia.org/wiki/Abul-Abbas',
#   'image': 'https://elephant-api.herokuapp.com/pictures/001.jpg',
#   'note': 'An elephant given to Carolingian emperor Charlemagne by the Abbasid caliph Harun al-Rashid.'},
#  {'_id': '5cf1d0db8c4845fb358b91d6',
#   'index': 2,
#   'name': 'Arjuna',
#   'affiliation': 'Dasara',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1960',
#   'dod': '-',
#   'wikilink': 'https://en.wikipedia.org/wiki/Arjuna_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/002.jpg',
#   'note': 'A lead elephant of the world-famous Mysore Dasara procession.'},
#  {'_id': '5cf1d0dbcd5e98f2540c4d1c',
#   'index': 3,
#   'name': 'Balarama',
#   'affiliation': 'Dasara',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1958',
#   'dod': '-',
#   'wikilink': 'https://en.wikipedia.org/wiki/Balarama_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A lead elephant of the world-famous Mysore Dasara procession.'},
#  {'_id': '5cf1d0dbe1b30267706da101',
#   'index': 5,
#   'name': 'Black Diamond',
#   'affiliation': 'Al G. Barnes Circus',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1898',
#   'dod': '1929',
#   'wikilink': 'https://en.wikipedia.org/wiki/Black_Diamond_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/005.jpg',
#   'note': 'Believed to be the largest Indian elephant in captivity.'},
#  {'_id': '5cf1d0db39d971a8ca87f8b1',
#   'index': 4,
#   'name': 'Batyr',
#   'affiliation': 'Karaganda Zoo',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1970',
#   'dod': '1993',
#   'wikilink': 'https://en.wikipedia.org/wiki/Batyr',
#   'image': 'https://elephant-api.herokuapp.com/pictures/004.jpg',
#   'note': 'An elephant claimed to be able to use a large amount of meaningful human speech, reported as having a vocabulary of more than 20 phrases.'},
#  {'_id': '5cf1d0db0574158b7a1c34f5',
#   'index': 7,
#   'name': 'Chunee',
#   'affiliation': 'Exeter Exchange',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1826',
#   'wikilink': 'https://en.wikipedia.org/wiki/Chunee',
#   'image': 'https://elephant-api.herokuapp.com/pictures/007.jpg',
#   'note': 'An elephant in the menagerie at Exeter Exchange, executed by soldiers from Somerset House in March 1826.'},
#  {'_id': '5cf1d0dbb3ae234b17062563',
#   'index': 6,
#   'name': 'Chengalloor Ranganathan',
#   'affiliation': 'Arattupuzha Pooram',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1927',
#   'wikilink': 'Unavailable',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'Considered the tallest Asian thatever lived. He was killed by another elephant during Arattupuzha Festival in 1927. The century-old skeleton of this elephant is exhibited in the Thrissur Museum in the Main Entrance hall.'},
#  {'_id': '5cf1d1adc46fd30ceb78ea71',
#   'index': 8,
#   'name': 'The Cremona Elephant',
#   'affiliation': 'Holy Roman Emperor Frederick II',
#   'species': 'Unavailable',
#   'sex': 'Unavailable',
#   'fictional': 'false',
#   'dob': '12XX',
#   'dod': 'Unavailable',
#   'wikilink': 'https://en.wikipedia.org/wiki/Cremona_elephant',
#   'image': 'https://elephant-api.herokuapp.com/pictures/008.jpg',
#   'note': 'A gift presented to Holy Roman Emperor Frederick II by Sultan of Egypt Al-Kamil, in 1229. Frederick used the elephant in his triumph parades.'},
#  {'_id': '5cf1d1ad31795d2421418824',
#   'index': 12,
#   'name': 'Hanno',
#   'affiliation': 'King Manuel I of Portugal',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1510',
#   'dod': '1516',
#   'wikilink': 'https://en.wikipedia.org/wiki/Hanno_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/012.jpg',
#   'note': 'The pet white elephant given by King Manuel I of Portugal to Pope Leo X at his coronation.'},
#  {'_id': '5cf1d1adc6d79601c0fa1286',
#   'index': 11,
#   'name': 'Fanny',
#   'affiliation': 'Slater Park Zoo, Rhode Island',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '2003',
#   'wikilink': 'https://en.wikipedia.org/wiki/Fanny_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/011.jpg',
#   'note': 'A female elephant who spent the majority of her life in a small zoo.'},
#  {'_id': '5cf1d1efb60e97c85ab4fc93',
#   'index': 13,
#   'name': 'Hansken',
#   'affiliation': 'Frederik Hendrik of Orange',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1630',
#   'dod': '1655',
#   'wikilink': 'https://en.wikipedia.org/wiki/Hansken',
#   'image': 'https://elephant-api.herokuapp.com/pictures/013.jpg',
#   'note': 'A female elephant that became famous in early 17th-century Europe. She toured many countries, demonstrating circus tricks, and was sketched by Rembrandt and Stefano della Bella.'},
#  {'_id': '5cf1d1efcf45c435dbecb9b7',
#   'index': 14,
#   'name': 'Hattie',
#   'affiliation': 'Central Park Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1922',
#   'wikilink': 'https://en.wikipedia.org/wiki/Hattie_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/014.jpg',
#   'note': 'An elephant in New York City\'s Central Park Zoo that was described as the "most intelligent of all elephants" and "nearly human."'},
#  {'_id': '5cf1d1ef243ea2e6069a4a44',
#   'index': 15,
#   'name': 'Isilo',
#   'affiliation': 'Tembe Elephant Park',
#   'species': 'African',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1956',
#   'dod': '2014',
#   'wikilink': 'https://en.wikipedia.org/wiki/Isilo_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'One of South Africa’s largest Africans and the largest living tusker (a male elephant with tusks weighing over 100 pounds) in the southern hemisphere before his death.'},
#  {'_id': '5cf1d1ef9bf1ce2d0844d8c6',
#   'index': 16,
#   'name': 'John L. Sullivan',
#   'affiliation': 'Adam Forepaugh Circus',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1860',
#   'dod': '1932',
#   'wikilink': 'https://en.wikipedia.org/wiki/John_L._Sullivan_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/016.jpg',
#   'note': "A boxing elephant in Adam Forepaugh's circus."},
#  {'_id': '5cf1d1add907cd9f9df047b1',
#   'index': 10,
#   'name': 'Echo',
#   'affiliation': 'Amboseli Elephant Research Project',
#   'species': 'African Bush Elephant',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1945',
#   'dod': '2009',
#   'wikilink': 'https://en.wikipedia.org/wiki/Echo_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/010.jpg',
#   'note': 'Most studied elephant in the world.'},
#  {'_id': '5cf1d229450aa1d22eb8515c',
#   'index': 18,
#   'name': 'Kashin',
#   'affiliation': 'Auckland Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1968',
#   'dod': '2009',
#   'wikilink': 'https://en.wikipedia.org/wiki/Kashin_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/018.jpg',
#   'note': 'Famous for being sponsored by ASB Bank, and featured in the New Zealand produced television programme The Zoo.'},
#  {'_id': '5cf1d1ef814468cd1e877a7e',
#   'index': 17,
#   'name': 'Jumbo',
#   'affiliation': 'P. T. Barnum',
#   'species': 'African',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1860',
#   'dod': '1885',
#   'wikilink': 'https://en.wikipedia.org/wiki/Jumbo',
#   'image': 'https://elephant-api.herokuapp.com/pictures/017.jpg',
#   'note': 'A 19th-century male African bush elephant born in Sudan. Jumbo was exported to Jardin des Plantes, a zoo in Paris, and then transferred in 1865 to London Zoo in England. Despite public protest, Jumbo was sold to P. T. Barnum, who took him to the United States for exhibition in March 1882.'},
#  {'_id': '5cf1d22923d1eb5854856999',
#   'index': 19,
#   'name': 'Kesavan',
#   'affiliation': 'Guruvayur Temple, Kerala, India',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1904',
#   'dod': '1976',
#   'wikilink': 'https://en.wikipedia.org/wiki/Guruvayur_Keshavan',
#   'image': 'https://elephant-api.herokuapp.com/pictures/019.jpg',
#   'note': 'Perhaps the most famous and celebrated temple elephant in Kerala, India. Keshavan was donated to the Guruvayur Hindu temple by the royal family of Nilambu.'},
#  {'_id': '5cf1d22986fdc62d2cfcdc28',
#   'index': 20,
#   'name': 'Kolakolli',
#   'affiliation': 'Peppara Wildlife Sanctuary',
#   'species': 'Asian',
#   'sex': 'Unavailable',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '2006',
#   'wikilink': 'https://en.wikipedia.org/wiki/Kolakolli',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'An Indian rogue elephant which gained considerable notoriety among Indian media and was accused of killing 12 people in and around Peppara over a span of seven to eight years.'},
#  {'_id': '5cf1d229b8bc2d4f70aa5b49',
#   'index': 21,
#   'name': 'Lallah Rookh',
#   'affiliation': 'Dan Rice Circus',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1860',
#   'wikilink': 'https://en.wikipedia.org/wiki/Lallah_Rookh',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A female elephant known for her tightrope walking act.'},
#  {'_id': '5cf1d1adf325fd6ad3176d33',
#   'index': 9,
#   'name': 'Drona',
#   'affiliation': 'Dasara',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1936',
#   'dod': '1998',
#   'wikilink': 'https://en.wikipedia.org/wiki/Drona_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'The lead Dasara Elephants of the Jamboo Savari of Mysore Dasara. He carried the Golden Howdah for a record 18 years consecutive years between 1981 and 1997, before being electrocuted while grazing in 1998.'},
#  {'_id': '5cf1d229c6e4d51fbb7523a7',
#   'index': 22,
#   'name': 'Lin Wang',
#   'affiliation': 'Taipei Zoo',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1917',
#   'dod': '2003',
#   'wikilink': 'https://en.wikipedia.org/wiki/Lin_Wang',
#   'image': 'https://elephant-api.herokuapp.com/pictures/022.jpg',
#   'note': 'Served with the Chinese Expeditionary Force during the Second Sino-Japanese War (1937–1945) and later relocated to Taiwan with the Kuomintang forces.'},
#  {'_id': '5cf1d2291b62a78c9e9ad1f2',
#   'index': 23,
#   'name': 'Mary',
#   'affiliation': 'Sparks World Famous Shows Circus',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1894',
#   'dod': '1916',
#   'wikilink': 'https://en.wikipedia.org/wiki/Mary_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/023.jpg',
#   'note': 'Also known as "Mighty Mary" and "Murderous Mary", this circus elephant was was hanged by a railroad derrick car after killing her inexperienced keeper. This is the only known elephant hanging in history.'},
#  {'_id': '5cf1d26746b81e3ade75512d',
#   'index': 24,
#   'name': 'Miss Jim',
#   'affiliation': 'St. Louis Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1948',
#   'wikilink': 'https://en.wikipedia.org/wiki/Miss_Jim',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A former circus elephant, bought for the zoo by the children of St. Louis who pooled their pennies for her purchase.'},
#  {'_id': '5cf1d26715dd3896b61a7ad6',
#   'index': 26,
#   'name': 'Motty',
#   'affiliation': 'Chester Zoo, Cheshire',
#   'species': 'Hybrid Elephant',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1978',
#   'dod': '1978',
#   'wikilink': 'https://en.wikipedia.org/wiki/Motty',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'Only confirmed Asian/African hybrid elephant.'},
#  {'_id': '5cf1d267a82e8e66cce0fe95',
#   'index': 25,
#   'name': 'Mona',
#   'affiliation': 'Birmingham Zoo, Alabama',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1951',
#   'dod': '2007',
#   'wikilink': 'https://en.wikipedia.org/wiki/Mona_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/025.jpg',
#   'note': 'Thought, at 60, to have been the oldest Asian in the United States.'},
#  {'_id': '5cf1d2671f2c519d698bc455',
#   'index': 29,
#   'name': 'Packy',
#   'affiliation': 'Oregon Zoo',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1962',
#   'dod': '2017',
#   'wikilink': 'https://en.wikipedia.org/wiki/Packy_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/029.jpg',
#   'note': 'First Asian born in the Western Hemisphere in 44 years.'},
#  {'_id': '5cf1d26746e076b4331cc680',
#   'index': 27,
#   'name': 'Old Bet',
#   'affiliation': 'Hachaliah Bailey',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1816',
#   'wikilink': 'https://en.wikipedia.org/wiki/Old_Bet',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'The first circus elephant and the second elephant brought to the United States.'},
#  {'_id': '5cf1d2c210735d003557514b',
#   'index': 31,
#   'name': 'Queenie',
#   'affiliation': 'Trefflich Pet Store',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1952',
#   'dod': '2011',
#   'wikilink': 'https://en.wikipedia.org/wiki/Queenie_(waterskiing_elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/031.jpg',
#   'note': 'A captive female Asian which was noted in the late 1950s and early 1960s for waterskiing for entertainment.'},
#  {'_id': '5cf1d2c28066a45f70fe1cad',
#   'index': 33,
#   'name': 'Raja Gaj',
#   'affiliation': 'Bardiya National Park, Nepal',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1936',
#   'dod': '2007',
#   'wikilink': 'https://en.wikipedia.org/wiki/Raja_Gaj',
#   'image': 'https://elephant-api.herokuapp.com/pictures/032.jpg',
#   'note': "Considered to be the world's largest Asian of modern times."},
#  {'_id': '5cf1d2c2280da34cb73abce5',
#   'index': 32,
#   'name': 'Raja',
#   'affiliation': 'Sri Dalada Maligawa, Kandy',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1913',
#   'dod': '1988',
#   'wikilink': 'https://en.wikipedia.org/wiki/Raja_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/032.jpg',
#   'note': 'A Sri Lankan tusker elephant which participated at the annual Esala procession in Kandy for around 50 years, and was declared as a national treasure, in recognition of his valuable services to the religion and culture of Sri Lanka.'},
#  {'_id': '5cf1d267441c5d5b2f308de0',
#   'index': 28,
#   'name': 'Osama bin Laden',
#   'affiliation': 'Assam, India',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '2006',
#   'wikilink': 'https://en.wikipedia.org/wiki/Osama_bin_Laden_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'Rogue elephant which killed at least 27 people in India from 2004 to 2006.'},
#  {'_id': '5cf1d2c2c9a0e486451f1d50',
#   'index': 34,
#   'name': 'Rajje',
#   'affiliation': 'William Pratt',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1951',
#   'dod': '1963',
#   'wikilink': 'https://en.wikipedia.org/wiki/Rajje_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A performing elephant that escaped into the streets of Lansing, Michigan, and was killed by gunfire.'},
#  {'_id': '5cf1d2c2710b7e2f14158323',
#   'index': 36,
#   'name': 'Ruby',
#   'affiliation': 'Phoenix Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1973',
#   'dod': '1998',
#   'wikilink': 'https://en.wikipedia.org/wiki/Ruby_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/036.jpg',
#   'note': 'An elephant famous for creating paintings. The most expensive of her paintings sold for $25,000.'},
#  {'_id': '5cf1d2c2feb0255713c56412',
#   'index': 35,
#   'name': 'Rosie',
#   'affiliation': 'Miami Beach, Florida',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1938',
#   'wikilink': 'https://en.wikipedia.org/wiki/Rosie_the_Elephant',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': "An instrumental figure in the history of the U.S. city of Miami Beach, Florida. Her appearance in publicity photos helped to contribute to the area's early reputation for being a place that a visitor had to see to believe."},
#  {'_id': '5cf1d324f53859b0353d9339',
#   'index': 37,
#   'name': 'Salt',
#   'affiliation': 'George William Lockhart',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1900',
#   'dod': '1952',
#   'wikilink': 'https://en.wikipedia.org/wiki/Salt_and_Sauce',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': "Salt and Sauce were once two of Britain's most famous and notorious performing elephants. Sauce killed her owner and trainer in an accident at Walthamstow Station and Salt killed an elephant groom when she attacked him in 1957 on Rosaire's Circus."},
#  {'_id': '5cf1d2c29eb2ce805401789d',
#   'index': 30,
#   'name': 'Queenie',
#   'affiliation': 'Melbourne Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1944',
#   'wikilink': 'https://en.wikipedia.org/wiki/Queenie_(Melbourne_elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/030.jpg',
#   'note': 'Gave rides for children at Melbourne Zoo for 40 years.'},
#  {'_id': '5cf1d32434d94cbfb43fd1c5',
#   'index': 38,
#   'name': 'Sauce',
#   'affiliation': 'George William Lockhart',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1900',
#   'dod': '1960',
#   'wikilink': 'https://en.wikipedia.org/wiki/Salt_and_Sauce',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': "Salt and Sauce were once two of Britain's most famous and notorious performing elephants. Sauce killed her owner and trainer in an accident at Walthamstow Station and Salt killed an elephant groom when she attacked him in 1957 on Rosaire's Circus."},
#  {'_id': '5cf1d324ebb6d39f48de496a',
#   'index': 42,
#   'name': 'Thiruvambadi Sivasundar',
#   'affiliation': 'Thiruvambadi Sri Krishna Temple, Kerala',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1972',
#   'dod': '2018',
#   'wikilink': 'https://en.wikipedia.org/wiki/Thiruvambadi_Sivasundar',
#   'image': 'https://elephant-api.herokuapp.com/pictures/042.jpg',
#   'note': 'An Indian elephant purchased by businessman Sundar Menon who gave him as an offering to the deity at the Thiruvambadi Sri Krishna Temple.'},
#  {'_id': '5cf1d3240ed9228bbef619df',
#   'index': 43,
#   'name': 'Tai',
#   'affiliation': 'Have Trunk Will Travel, Inc.',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1968',
#   'dod': '-',
#   'wikilink': 'https://en.wikipedia.org/wiki/Tai_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'Known for featuring in the films Larger than Life and Water for Elephants.'},
#  {'_id': '5cf1d324eb450b52a52ba78d',
#   'index': 40,
#   'name': 'Suleiman',
#   'affiliation': 'Maximilian II',
#   'species': 'African',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1540',
#   'dod': '1553',
#   'wikilink': 'https://en.wikipedia.org/wiki/Suleiman_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/040.jpg',
#   'note': 'Presented in 1551 to Maximilian II, the Holy Roman Emperor, by John III, the King of Portugal, and named after the Ottoman Sultan, Suleiman the Magnificent.'},
#  {'_id': '5cf1d374e96c3d81cb2d89dd',
#   'index': 44,
#   'name': 'Topsy',
#   'affiliation': 'Forepaugh Circus',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1875',
#   'dod': '1903',
#   'wikilink': 'https://en.wikipedia.org/wiki/Topsy_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/044.jpg',
#   'note': 'Killed a spectator who burned her trunk with a lit cigar. In 1903 the owners of a Coney Island park where she ended up publicly executed her via poison, electrocution, and strangling. The Edison Manufacturing movie company shot a film of the execution called Electrocuting an Elephant.'},
#  {'_id': '5cf1d32474fdff06d314da6a',
#   'index': 41,
#   'name': 'Surus',
#   'affiliation': 'Hannibal',
#   'species': 'Asian',
#   'sex': 'Unavailable',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': 'Unavailable',
#   'wikilink': 'https://en.wikipedia.org/wiki/Surus',
#   'image': 'https://elephant-api.herokuapp.com/pictures/041.jpg',
#   'note': "Mentioned as the bravest of Hannibal's 37 war elephants which crossed the Alps in 218 BC during the Second Punic War, by Cato the Elder in his book Origines."},
#  {'_id': '5cf1d37401c6112c72ee2489',
#   'index': 45,
#   'name': 'Tuffi',
#   'affiliation': 'Cirque Alexis Gruss',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1946',
#   'dod': '1989',
#   'wikilink': 'https://en.wikipedia.org/wiki/Tuffi',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A female circus elephant that became famous in Germany during 1950 when she accidentally fell into the River Wupper, and survived.'},
#  {'_id': '5cf1d374b45cf5da3bd9d810',
#   'index': 46,
#   'name': 'Tyke',
#   'affiliation': 'Circus International, Honolulu, Hawaii',
#   'species': 'African',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1974',
#   'dod': '1994',
#   'wikilink': 'https://en.wikipedia.org/wiki/Tyke_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/046.jpg',
#   'note': 'A circus elephant who killed her trainer Allen Campbell and injured her groom Dallas Beckwith before hundreds of spectators. She then bolted from the arena and ran through downtown streets for more than 30 minutes. Police fired 86 shots at Tyke, who eventually collapsed from the wounds and died.'},
#  {'_id': '5cf1d3741ca55f34f8561400',
#   'index': 47,
#   'name': 'Ziggy',
#   'affiliation': 'Brookfield Zoo',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1917',
#   'dod': '1975',
#   'wikilink': 'https://en.wikipedia.org/wiki/Ziggy_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'After attacking and nearly killing his keeper, Ziggy was chained to the wall of an indoor enclosure, and remained there for nearly three decades. In the late 1960s, when school children and other animal enthusiasts began campaigning for his release, eventually winning the case.'},
#  {'_id': '5cf1d324458ad7dd80a510ce',
#   'index': 39,
#   'name': 'Satao',
#   'affiliation': 'Tsavo East National Park',
#   'species': 'African',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1968',
#   'dod': '2014',
#   'wikilink': 'https://en.wikipedia.org/wiki/Satao_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/039.jpg',
#   'note': "One of Kenya's largest Africans, which had unusually large tusks and was killed by poachers."}]

# %%
elephants = req.json()

# %%
elephants
# Out:
# [{'_id': '5cf1d0db3cfbe0fcbb6c4c93',
#   'index': 1,
#   'name': 'Abul-Abbas',
#   'affiliation': 'Charlemagne',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '810',
#   'wikilink': 'https://en.wikipedia.org/wiki/Abul-Abbas',
#   'image': 'https://elephant-api.herokuapp.com/pictures/001.jpg',
#   'note': 'An elephant given to Carolingian emperor Charlemagne by the Abbasid caliph Harun al-Rashid.'},
#  {'_id': '5cf1d0db8c4845fb358b91d6',
#   'index': 2,
#   'name': 'Arjuna',
#   'affiliation': 'Dasara',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1960',
#   'dod': '-',
#   'wikilink': 'https://en.wikipedia.org/wiki/Arjuna_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/002.jpg',
#   'note': 'A lead elephant of the world-famous Mysore Dasara procession.'},
#  {'_id': '5cf1d0dbcd5e98f2540c4d1c',
#   'index': 3,
#   'name': 'Balarama',
#   'affiliation': 'Dasara',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1958',
#   'dod': '-',
#   'wikilink': 'https://en.wikipedia.org/wiki/Balarama_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A lead elephant of the world-famous Mysore Dasara procession.'},
#  {'_id': '5cf1d0dbe1b30267706da101',
#   'index': 5,
#   'name': 'Black Diamond',
#   'affiliation': 'Al G. Barnes Circus',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1898',
#   'dod': '1929',
#   'wikilink': 'https://en.wikipedia.org/wiki/Black_Diamond_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/005.jpg',
#   'note': 'Believed to be the largest Indian elephant in captivity.'},
#  {'_id': '5cf1d0db39d971a8ca87f8b1',
#   'index': 4,
#   'name': 'Batyr',
#   'affiliation': 'Karaganda Zoo',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1970',
#   'dod': '1993',
#   'wikilink': 'https://en.wikipedia.org/wiki/Batyr',
#   'image': 'https://elephant-api.herokuapp.com/pictures/004.jpg',
#   'note': 'An elephant claimed to be able to use a large amount of meaningful human speech, reported as having a vocabulary of more than 20 phrases.'},
#  {'_id': '5cf1d0db0574158b7a1c34f5',
#   'index': 7,
#   'name': 'Chunee',
#   'affiliation': 'Exeter Exchange',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1826',
#   'wikilink': 'https://en.wikipedia.org/wiki/Chunee',
#   'image': 'https://elephant-api.herokuapp.com/pictures/007.jpg',
#   'note': 'An elephant in the menagerie at Exeter Exchange, executed by soldiers from Somerset House in March 1826.'},
#  {'_id': '5cf1d0dbb3ae234b17062563',
#   'index': 6,
#   'name': 'Chengalloor Ranganathan',
#   'affiliation': 'Arattupuzha Pooram',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1927',
#   'wikilink': 'Unavailable',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'Considered the tallest Asian thatever lived. He was killed by another elephant during Arattupuzha Festival in 1927. The century-old skeleton of this elephant is exhibited in the Thrissur Museum in the Main Entrance hall.'},
#  {'_id': '5cf1d1adc46fd30ceb78ea71',
#   'index': 8,
#   'name': 'The Cremona Elephant',
#   'affiliation': 'Holy Roman Emperor Frederick II',
#   'species': 'Unavailable',
#   'sex': 'Unavailable',
#   'fictional': 'false',
#   'dob': '12XX',
#   'dod': 'Unavailable',
#   'wikilink': 'https://en.wikipedia.org/wiki/Cremona_elephant',
#   'image': 'https://elephant-api.herokuapp.com/pictures/008.jpg',
#   'note': 'A gift presented to Holy Roman Emperor Frederick II by Sultan of Egypt Al-Kamil, in 1229. Frederick used the elephant in his triumph parades.'},
#  {'_id': '5cf1d1ad31795d2421418824',
#   'index': 12,
#   'name': 'Hanno',
#   'affiliation': 'King Manuel I of Portugal',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1510',
#   'dod': '1516',
#   'wikilink': 'https://en.wikipedia.org/wiki/Hanno_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/012.jpg',
#   'note': 'The pet white elephant given by King Manuel I of Portugal to Pope Leo X at his coronation.'},
#  {'_id': '5cf1d1adc6d79601c0fa1286',
#   'index': 11,
#   'name': 'Fanny',
#   'affiliation': 'Slater Park Zoo, Rhode Island',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '2003',
#   'wikilink': 'https://en.wikipedia.org/wiki/Fanny_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/011.jpg',
#   'note': 'A female elephant who spent the majority of her life in a small zoo.'},
#  {'_id': '5cf1d1efb60e97c85ab4fc93',
#   'index': 13,
#   'name': 'Hansken',
#   'affiliation': 'Frederik Hendrik of Orange',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1630',
#   'dod': '1655',
#   'wikilink': 'https://en.wikipedia.org/wiki/Hansken',
#   'image': 'https://elephant-api.herokuapp.com/pictures/013.jpg',
#   'note': 'A female elephant that became famous in early 17th-century Europe. She toured many countries, demonstrating circus tricks, and was sketched by Rembrandt and Stefano della Bella.'},
#  {'_id': '5cf1d1efcf45c435dbecb9b7',
#   'index': 14,
#   'name': 'Hattie',
#   'affiliation': 'Central Park Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1922',
#   'wikilink': 'https://en.wikipedia.org/wiki/Hattie_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/014.jpg',
#   'note': 'An elephant in New York City\'s Central Park Zoo that was described as the "most intelligent of all elephants" and "nearly human."'},
#  {'_id': '5cf1d1ef243ea2e6069a4a44',
#   'index': 15,
#   'name': 'Isilo',
#   'affiliation': 'Tembe Elephant Park',
#   'species': 'African',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1956',
#   'dod': '2014',
#   'wikilink': 'https://en.wikipedia.org/wiki/Isilo_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'One of South Africa’s largest Africans and the largest living tusker (a male elephant with tusks weighing over 100 pounds) in the southern hemisphere before his death.'},
#  {'_id': '5cf1d1ef9bf1ce2d0844d8c6',
#   'index': 16,
#   'name': 'John L. Sullivan',
#   'affiliation': 'Adam Forepaugh Circus',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1860',
#   'dod': '1932',
#   'wikilink': 'https://en.wikipedia.org/wiki/John_L._Sullivan_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/016.jpg',
#   'note': "A boxing elephant in Adam Forepaugh's circus."},
#  {'_id': '5cf1d1add907cd9f9df047b1',
#   'index': 10,
#   'name': 'Echo',
#   'affiliation': 'Amboseli Elephant Research Project',
#   'species': 'African Bush Elephant',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1945',
#   'dod': '2009',
#   'wikilink': 'https://en.wikipedia.org/wiki/Echo_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/010.jpg',
#   'note': 'Most studied elephant in the world.'},
#  {'_id': '5cf1d229450aa1d22eb8515c',
#   'index': 18,
#   'name': 'Kashin',
#   'affiliation': 'Auckland Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1968',
#   'dod': '2009',
#   'wikilink': 'https://en.wikipedia.org/wiki/Kashin_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/018.jpg',
#   'note': 'Famous for being sponsored by ASB Bank, and featured in the New Zealand produced television programme The Zoo.'},
#  {'_id': '5cf1d1ef814468cd1e877a7e',
#   'index': 17,
#   'name': 'Jumbo',
#   'affiliation': 'P. T. Barnum',
#   'species': 'African',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1860',
#   'dod': '1885',
#   'wikilink': 'https://en.wikipedia.org/wiki/Jumbo',
#   'image': 'https://elephant-api.herokuapp.com/pictures/017.jpg',
#   'note': 'A 19th-century male African bush elephant born in Sudan. Jumbo was exported to Jardin des Plantes, a zoo in Paris, and then transferred in 1865 to London Zoo in England. Despite public protest, Jumbo was sold to P. T. Barnum, who took him to the United States for exhibition in March 1882.'},
#  {'_id': '5cf1d22923d1eb5854856999',
#   'index': 19,
#   'name': 'Kesavan',
#   'affiliation': 'Guruvayur Temple, Kerala, India',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1904',
#   'dod': '1976',
#   'wikilink': 'https://en.wikipedia.org/wiki/Guruvayur_Keshavan',
#   'image': 'https://elephant-api.herokuapp.com/pictures/019.jpg',
#   'note': 'Perhaps the most famous and celebrated temple elephant in Kerala, India. Keshavan was donated to the Guruvayur Hindu temple by the royal family of Nilambu.'},
#  {'_id': '5cf1d22986fdc62d2cfcdc28',
#   'index': 20,
#   'name': 'Kolakolli',
#   'affiliation': 'Peppara Wildlife Sanctuary',
#   'species': 'Asian',
#   'sex': 'Unavailable',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '2006',
#   'wikilink': 'https://en.wikipedia.org/wiki/Kolakolli',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'An Indian rogue elephant which gained considerable notoriety among Indian media and was accused of killing 12 people in and around Peppara over a span of seven to eight years.'},
#  {'_id': '5cf1d229b8bc2d4f70aa5b49',
#   'index': 21,
#   'name': 'Lallah Rookh',
#   'affiliation': 'Dan Rice Circus',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1860',
#   'wikilink': 'https://en.wikipedia.org/wiki/Lallah_Rookh',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A female elephant known for her tightrope walking act.'},
#  {'_id': '5cf1d1adf325fd6ad3176d33',
#   'index': 9,
#   'name': 'Drona',
#   'affiliation': 'Dasara',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1936',
#   'dod': '1998',
#   'wikilink': 'https://en.wikipedia.org/wiki/Drona_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'The lead Dasara Elephants of the Jamboo Savari of Mysore Dasara. He carried the Golden Howdah for a record 18 years consecutive years between 1981 and 1997, before being electrocuted while grazing in 1998.'},
#  {'_id': '5cf1d229c6e4d51fbb7523a7',
#   'index': 22,
#   'name': 'Lin Wang',
#   'affiliation': 'Taipei Zoo',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1917',
#   'dod': '2003',
#   'wikilink': 'https://en.wikipedia.org/wiki/Lin_Wang',
#   'image': 'https://elephant-api.herokuapp.com/pictures/022.jpg',
#   'note': 'Served with the Chinese Expeditionary Force during the Second Sino-Japanese War (1937–1945) and later relocated to Taiwan with the Kuomintang forces.'},
#  {'_id': '5cf1d2291b62a78c9e9ad1f2',
#   'index': 23,
#   'name': 'Mary',
#   'affiliation': 'Sparks World Famous Shows Circus',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1894',
#   'dod': '1916',
#   'wikilink': 'https://en.wikipedia.org/wiki/Mary_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/023.jpg',
#   'note': 'Also known as "Mighty Mary" and "Murderous Mary", this circus elephant was was hanged by a railroad derrick car after killing her inexperienced keeper. This is the only known elephant hanging in history.'},
#  {'_id': '5cf1d26746b81e3ade75512d',
#   'index': 24,
#   'name': 'Miss Jim',
#   'affiliation': 'St. Louis Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1948',
#   'wikilink': 'https://en.wikipedia.org/wiki/Miss_Jim',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A former circus elephant, bought for the zoo by the children of St. Louis who pooled their pennies for her purchase.'},
#  {'_id': '5cf1d26715dd3896b61a7ad6',
#   'index': 26,
#   'name': 'Motty',
#   'affiliation': 'Chester Zoo, Cheshire',
#   'species': 'Hybrid Elephant',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1978',
#   'dod': '1978',
#   'wikilink': 'https://en.wikipedia.org/wiki/Motty',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'Only confirmed Asian/African hybrid elephant.'},
#  {'_id': '5cf1d267a82e8e66cce0fe95',
#   'index': 25,
#   'name': 'Mona',
#   'affiliation': 'Birmingham Zoo, Alabama',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1951',
#   'dod': '2007',
#   'wikilink': 'https://en.wikipedia.org/wiki/Mona_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/025.jpg',
#   'note': 'Thought, at 60, to have been the oldest Asian in the United States.'},
#  {'_id': '5cf1d2671f2c519d698bc455',
#   'index': 29,
#   'name': 'Packy',
#   'affiliation': 'Oregon Zoo',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1962',
#   'dod': '2017',
#   'wikilink': 'https://en.wikipedia.org/wiki/Packy_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/029.jpg',
#   'note': 'First Asian born in the Western Hemisphere in 44 years.'},
#  {'_id': '5cf1d26746e076b4331cc680',
#   'index': 27,
#   'name': 'Old Bet',
#   'affiliation': 'Hachaliah Bailey',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1816',
#   'wikilink': 'https://en.wikipedia.org/wiki/Old_Bet',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'The first circus elephant and the second elephant brought to the United States.'},
#  {'_id': '5cf1d2c210735d003557514b',
#   'index': 31,
#   'name': 'Queenie',
#   'affiliation': 'Trefflich Pet Store',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1952',
#   'dod': '2011',
#   'wikilink': 'https://en.wikipedia.org/wiki/Queenie_(waterskiing_elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/031.jpg',
#   'note': 'A captive female Asian which was noted in the late 1950s and early 1960s for waterskiing for entertainment.'},
#  {'_id': '5cf1d2c28066a45f70fe1cad',
#   'index': 33,
#   'name': 'Raja Gaj',
#   'affiliation': 'Bardiya National Park, Nepal',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1936',
#   'dod': '2007',
#   'wikilink': 'https://en.wikipedia.org/wiki/Raja_Gaj',
#   'image': 'https://elephant-api.herokuapp.com/pictures/032.jpg',
#   'note': "Considered to be the world's largest Asian of modern times."},
#  {'_id': '5cf1d2c2280da34cb73abce5',
#   'index': 32,
#   'name': 'Raja',
#   'affiliation': 'Sri Dalada Maligawa, Kandy',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1913',
#   'dod': '1988',
#   'wikilink': 'https://en.wikipedia.org/wiki/Raja_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/032.jpg',
#   'note': 'A Sri Lankan tusker elephant which participated at the annual Esala procession in Kandy for around 50 years, and was declared as a national treasure, in recognition of his valuable services to the religion and culture of Sri Lanka.'},
#  {'_id': '5cf1d267441c5d5b2f308de0',
#   'index': 28,
#   'name': 'Osama bin Laden',
#   'affiliation': 'Assam, India',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '2006',
#   'wikilink': 'https://en.wikipedia.org/wiki/Osama_bin_Laden_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'Rogue elephant which killed at least 27 people in India from 2004 to 2006.'},
#  {'_id': '5cf1d2c2c9a0e486451f1d50',
#   'index': 34,
#   'name': 'Rajje',
#   'affiliation': 'William Pratt',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1951',
#   'dod': '1963',
#   'wikilink': 'https://en.wikipedia.org/wiki/Rajje_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A performing elephant that escaped into the streets of Lansing, Michigan, and was killed by gunfire.'},
#  {'_id': '5cf1d2c2710b7e2f14158323',
#   'index': 36,
#   'name': 'Ruby',
#   'affiliation': 'Phoenix Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1973',
#   'dod': '1998',
#   'wikilink': 'https://en.wikipedia.org/wiki/Ruby_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/036.jpg',
#   'note': 'An elephant famous for creating paintings. The most expensive of her paintings sold for $25,000.'},
#  {'_id': '5cf1d2c2feb0255713c56412',
#   'index': 35,
#   'name': 'Rosie',
#   'affiliation': 'Miami Beach, Florida',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1938',
#   'wikilink': 'https://en.wikipedia.org/wiki/Rosie_the_Elephant',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': "An instrumental figure in the history of the U.S. city of Miami Beach, Florida. Her appearance in publicity photos helped to contribute to the area's early reputation for being a place that a visitor had to see to believe."},
#  {'_id': '5cf1d324f53859b0353d9339',
#   'index': 37,
#   'name': 'Salt',
#   'affiliation': 'George William Lockhart',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1900',
#   'dod': '1952',
#   'wikilink': 'https://en.wikipedia.org/wiki/Salt_and_Sauce',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': "Salt and Sauce were once two of Britain's most famous and notorious performing elephants. Sauce killed her owner and trainer in an accident at Walthamstow Station and Salt killed an elephant groom when she attacked him in 1957 on Rosaire's Circus."},
#  {'_id': '5cf1d2c29eb2ce805401789d',
#   'index': 30,
#   'name': 'Queenie',
#   'affiliation': 'Melbourne Zoo',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': '1944',
#   'wikilink': 'https://en.wikipedia.org/wiki/Queenie_(Melbourne_elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/030.jpg',
#   'note': 'Gave rides for children at Melbourne Zoo for 40 years.'},
#  {'_id': '5cf1d32434d94cbfb43fd1c5',
#   'index': 38,
#   'name': 'Sauce',
#   'affiliation': 'George William Lockhart',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1900',
#   'dod': '1960',
#   'wikilink': 'https://en.wikipedia.org/wiki/Salt_and_Sauce',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': "Salt and Sauce were once two of Britain's most famous and notorious performing elephants. Sauce killed her owner and trainer in an accident at Walthamstow Station and Salt killed an elephant groom when she attacked him in 1957 on Rosaire's Circus."},
#  {'_id': '5cf1d324ebb6d39f48de496a',
#   'index': 42,
#   'name': 'Thiruvambadi Sivasundar',
#   'affiliation': 'Thiruvambadi Sri Krishna Temple, Kerala',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1972',
#   'dod': '2018',
#   'wikilink': 'https://en.wikipedia.org/wiki/Thiruvambadi_Sivasundar',
#   'image': 'https://elephant-api.herokuapp.com/pictures/042.jpg',
#   'note': 'An Indian elephant purchased by businessman Sundar Menon who gave him as an offering to the deity at the Thiruvambadi Sri Krishna Temple.'},
#  {'_id': '5cf1d3240ed9228bbef619df',
#   'index': 43,
#   'name': 'Tai',
#   'affiliation': 'Have Trunk Will Travel, Inc.',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1968',
#   'dod': '-',
#   'wikilink': 'https://en.wikipedia.org/wiki/Tai_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'Known for featuring in the films Larger than Life and Water for Elephants.'},
#  {'_id': '5cf1d324eb450b52a52ba78d',
#   'index': 40,
#   'name': 'Suleiman',
#   'affiliation': 'Maximilian II',
#   'species': 'African',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1540',
#   'dod': '1553',
#   'wikilink': 'https://en.wikipedia.org/wiki/Suleiman_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/040.jpg',
#   'note': 'Presented in 1551 to Maximilian II, the Holy Roman Emperor, by John III, the King of Portugal, and named after the Ottoman Sultan, Suleiman the Magnificent.'},
#  {'_id': '5cf1d374e96c3d81cb2d89dd',
#   'index': 44,
#   'name': 'Topsy',
#   'affiliation': 'Forepaugh Circus',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1875',
#   'dod': '1903',
#   'wikilink': 'https://en.wikipedia.org/wiki/Topsy_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/044.jpg',
#   'note': 'Killed a spectator who burned her trunk with a lit cigar. In 1903 the owners of a Coney Island park where she ended up publicly executed her via poison, electrocution, and strangling. The Edison Manufacturing movie company shot a film of the execution called Electrocuting an Elephant.'},
#  {'_id': '5cf1d32474fdff06d314da6a',
#   'index': 41,
#   'name': 'Surus',
#   'affiliation': 'Hannibal',
#   'species': 'Asian',
#   'sex': 'Unavailable',
#   'fictional': 'false',
#   'dob': 'Unavailable',
#   'dod': 'Unavailable',
#   'wikilink': 'https://en.wikipedia.org/wiki/Surus',
#   'image': 'https://elephant-api.herokuapp.com/pictures/041.jpg',
#   'note': "Mentioned as the bravest of Hannibal's 37 war elephants which crossed the Alps in 218 BC during the Second Punic War, by Cato the Elder in his book Origines."},
#  {'_id': '5cf1d37401c6112c72ee2489',
#   'index': 45,
#   'name': 'Tuffi',
#   'affiliation': 'Cirque Alexis Gruss',
#   'species': 'Asian',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1946',
#   'dod': '1989',
#   'wikilink': 'https://en.wikipedia.org/wiki/Tuffi',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'A female circus elephant that became famous in Germany during 1950 when she accidentally fell into the River Wupper, and survived.'},
#  {'_id': '5cf1d374b45cf5da3bd9d810',
#   'index': 46,
#   'name': 'Tyke',
#   'affiliation': 'Circus International, Honolulu, Hawaii',
#   'species': 'African',
#   'sex': 'Female',
#   'fictional': 'false',
#   'dob': '1974',
#   'dod': '1994',
#   'wikilink': 'https://en.wikipedia.org/wiki/Tyke_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/046.jpg',
#   'note': 'A circus elephant who killed her trainer Allen Campbell and injured her groom Dallas Beckwith before hundreds of spectators. She then bolted from the arena and ran through downtown streets for more than 30 minutes. Police fired 86 shots at Tyke, who eventually collapsed from the wounds and died.'},
#  {'_id': '5cf1d3741ca55f34f8561400',
#   'index': 47,
#   'name': 'Ziggy',
#   'affiliation': 'Brookfield Zoo',
#   'species': 'Asian',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1917',
#   'dod': '1975',
#   'wikilink': 'https://en.wikipedia.org/wiki/Ziggy_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/missing.jpg',
#   'note': 'After attacking and nearly killing his keeper, Ziggy was chained to the wall of an indoor enclosure, and remained there for nearly three decades. In the late 1960s, when school children and other animal enthusiasts began campaigning for his release, eventually winning the case.'},
#  {'_id': '5cf1d324458ad7dd80a510ce',
#   'index': 39,
#   'name': 'Satao',
#   'affiliation': 'Tsavo East National Park',
#   'species': 'African',
#   'sex': 'Male',
#   'fictional': 'false',
#   'dob': '1968',
#   'dod': '2014',
#   'wikilink': 'https://en.wikipedia.org/wiki/Satao_(elephant)',
#   'image': 'https://elephant-api.herokuapp.com/pictures/039.jpg',
#   'note': "One of Kenya's largest Africans, which had unusually large tusks and was killed by poachers."}]

# %%
type(elephants)
# Out:
# list

# %%
for elephant in elephants:
    print(elephant['_id'])
# Out:
# 5cf1d0db3cfbe0fcbb6c4c93
# 5cf1d0db8c4845fb358b91d6
# 5cf1d0dbcd5e98f2540c4d1c
# 5cf1d0dbe1b30267706da101
# 5cf1d0db39d971a8ca87f8b1
# 5cf1d0db0574158b7a1c34f5
# 5cf1d0dbb3ae234b17062563
# 5cf1d1adc46fd30ceb78ea71
# 5cf1d1ad31795d2421418824
# 5cf1d1adc6d79601c0fa1286
# 5cf1d1efb60e97c85ab4fc93
# 5cf1d1efcf45c435dbecb9b7
# 5cf1d1ef243ea2e6069a4a44
# 5cf1d1ef9bf1ce2d0844d8c6
# 5cf1d1add907cd9f9df047b1
# 5cf1d229450aa1d22eb8515c
# 5cf1d1ef814468cd1e877a7e
# 5cf1d22923d1eb5854856999
# 5cf1d22986fdc62d2cfcdc28
# 5cf1d229b8bc2d4f70aa5b49
# 5cf1d1adf325fd6ad3176d33
# 5cf1d229c6e4d51fbb7523a7
# 5cf1d2291b62a78c9e9ad1f2
# 5cf1d26746b81e3ade75512d
# 5cf1d26715dd3896b61a7ad6
# 5cf1d267a82e8e66cce0fe95
# 5cf1d2671f2c519d698bc455
# 5cf1d26746e076b4331cc680
# 5cf1d2c210735d003557514b
# 5cf1d2c28066a45f70fe1cad
# 5cf1d2c2280da34cb73abce5
# 5cf1d267441c5d5b2f308de0
# 5cf1d2c2c9a0e486451f1d50
# 5cf1d2c2710b7e2f14158323
# 5cf1d2c2feb0255713c56412
# 5cf1d324f53859b0353d9339
# 5cf1d2c29eb2ce805401789d
# 5cf1d32434d94cbfb43fd1c5
# 5cf1d324ebb6d39f48de496a
# 5cf1d3240ed9228bbef619df
# 5cf1d324eb450b52a52ba78d
# 5cf1d374e96c3d81cb2d89dd
# 5cf1d32474fdff06d314da6a
# 5cf1d37401c6112c72ee2489
# 5cf1d374b45cf5da3bd9d810
# 5cf1d3741ca55f34f8561400
# 5cf1d324458ad7dd80a510ce

# %% [markdown]
# ### Create a function that can create a dictionary given a list of json

# %%
for elephant in elephants:
    print(elephant['name'])
# Out:
# Abul-Abbas
# Arjuna
# Balarama
# Black Diamond
# Batyr
# Chunee
# Chengalloor Ranganathan
# The Cremona Elephant
# Hanno
# Fanny
# Hansken
# Hattie
# Isilo
# John L. Sullivan
# Echo
# Kashin
# Jumbo
# Kesavan
# Kolakolli
# Lallah Rookh
# Drona
# Lin Wang
# Mary
# Miss Jim
# Motty
# Mona
# Packy
# Old Bet
# Queenie
# Raja Gaj
# Raja
# Osama bin Laden
# Rajje
# Ruby
# Rosie
# Salt
# Queenie
# Sauce
# Thiruvambadi Sivasundar
# Tai
# Suleiman
# Topsy
# Surus
# Tuffi
# Tyke
# Ziggy
# Satao

# %%
def create_elephant_dictionary(elephants):
        elephants_dictionary = {}
        for elephant in elephants:
            id = elephant['_id']
            name = elephant['name']
            species = elephant['species']
            note = elephant['note']
            affiliation = elephant['affiliation']
            sex = elephant['sex']
            image = elephant['image']
            elephants_dictionary[id] = [name,affiliation,species,sex,note,image]
        return elephants_dictionary

# %%
df = create_elephant_dictionary(elephants)

# %%
elephants_df = pd.DataFrame(df)

# %%
elephants_df
# Out:
#                             5cf1d0db3cfbe0fcbb6c4c93  \
# 0                                         Abul-Abbas
# 1                                        Charlemagne
# 2                                              Asian
# 3                                               Male
# 4  An elephant given to Carolingian emperor Charl...
# 5  https://elephant-api.herokuapp.com/pictures/00...
#
#                             5cf1d0db8c4845fb358b91d6  \
# 0                                             Arjuna
# 1                                             Dasara
# 2                                              Asian
# 3                                               Male
# 4  A lead elephant of the world-famous Mysore Das...
# 5  https://elephant-api.herokuapp.com/pictures/00...
#
#                             5cf1d0dbcd5e98f2540c4d1c  \
# 0                                           Balarama
# 1                                             Dasara
# 2                                              Asian
# 3                                               Male
# 4  A lead elephant of the world-famous Mysore Das...
# 5  https://elephant-api.herokuapp.com/pictures/mi...
#
#                             5cf1d0dbe1b30267706da101  \
# 0                                      Black Diamond
# 1                                Al G. Barnes Circus
# 2                                              Asian
# 3                                               Male
# 4  Believed to be the largest Indian elephant in ...
# 5  https://elephant-api.herokuapp.com/pictures/00...
#
#                             5cf1d0db39d971a8ca87f8b1  \
# 0                                              Batyr
# 1                                      Karaganda Zoo
# 2                                              Asian
# 3                                               Male
# 4  An elephant claimed to be able to use a large ...
# 5  https://elephant-api.herokuapp.com/pictures/00...
#
#                             5cf1d0db0574158b7a1c34f5  \
# 0                                             Chunee
# 1                                    Exeter Exchange
# 2                                              Asian
# 3                                               Male
# 4  An elephant in the menagerie at Exeter Exchang...
# 5  https://elephant-api.herokuapp.com/pictures/00...
#
#                             5cf1d0dbb3ae234b17062563  \
# 0                            Chengalloor Ranganathan
# 1                                 Arattupuzha Pooram
# 2                                              Asian
# 3                                               Male
# 4  Considered the tallest Asian thatever lived. H...
# 5  https://elephant-api.herokuapp.com/pictures/mi...
#
#                             5cf1d1adc46fd30ceb78ea71  \
# 0                               The Cremona Elephant
# 1                    Holy Roman Emperor Frederick II
# 2                                        Unavailable
# 3                                        Unavailable
# 4  A gift presented to Holy Roman Emperor Frederi...
# 5  https://elephant-api.herokuapp.com/pictures/00...
#
#                             5cf1d1ad31795d2421418824  \
# 0                                              Hanno
# 1                          King Manuel I of Portugal
# 2                                              Asian
# 3                                               Male
# 4  The pet white elephant given by King Manuel I ...
# 5  https://elephant-api.herokuapp.com/pictures/01...
#
#                             5cf1d1adc6d79601c0fa1286  \
# 0                                              Fanny
# 1                      Slater Park Zoo, Rhode Island
# 2                                              Asian
# 3                                             Female
# 4  A female elephant who spent the majority of he...
# 5  https://elephant-api.herokuapp.com/pictures/01...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
# 5                        ...
#
#                             5cf1d32434d94cbfb43fd1c5  \
# 0                                              Sauce
# 1                            George William Lockhart
# 2                                              Asian
# 3                                             Female
# 4  Salt and Sauce were once two of Britain's most...
# 5  https://elephant-api.herokuapp.com/pictures/mi...
#
#                             5cf1d324ebb6d39f48de496a  \
# 0                            Thiruvambadi Sivasundar
# 1            Thiruvambadi Sri Krishna Temple, Kerala
# 2                                              Asian
# 3                                               Male
# 4  An Indian elephant purchased by businessman Su...
# 5  https://elephant-api.herokuapp.com/pictures/04...
#
#                             5cf1d3240ed9228bbef619df  \
# 0                                                Tai
# 1                       Have Trunk Will Travel, Inc.
# 2                                              Asian
# 3                                             Female
# 4  Known for featuring in the films Larger than L...
# 5  https://elephant-api.herokuapp.com/pictures/mi...
#
#                             5cf1d324eb450b52a52ba78d  \
# 0                                           Suleiman
# 1                                      Maximilian II
# 2                                            African
# 3                                               Male
# 4  Presented in 1551 to Maximilian II, the Holy R...
# 5  https://elephant-api.herokuapp.com/pictures/04...
#
#                             5cf1d374e96c3d81cb2d89dd  \
# 0                                              Topsy
# 1                                   Forepaugh Circus
# 2                                              Asian
# 3                                             Female
# 4  Killed a spectator who burned her trunk with a...
# 5  https://elephant-api.herokuapp.com/pictures/04...
#
#                             5cf1d32474fdff06d314da6a  \
# 0                                              Surus
# 1                                           Hannibal
# 2                                              Asian
# 3                                        Unavailable
# 4  Mentioned as the bravest of Hannibal's 37 war ...
# 5  https://elephant-api.herokuapp.com/pictures/04...
#
#                             5cf1d37401c6112c72ee2489  \
# 0                                              Tuffi
# 1                                Cirque Alexis Gruss
# 2                                              Asian
# 3                                             Female
# 4  A female circus elephant that became famous in...
# 5  https://elephant-api.herokuapp.com/pictures/mi...
#
#                             5cf1d374b45cf5da3bd9d810  \
# 0                                               Tyke
# 1             Circus International, Honolulu, Hawaii
# 2                                            African
# 3                                             Female
# 4  A circus elephant who killed her trainer Allen...
# 5  https://elephant-api.herokuapp.com/pictures/04...
#
#                             5cf1d3741ca55f34f8561400  \
# 0                                              Ziggy
# 1                                     Brookfield Zoo
# 2                                              Asian
# 3                                               Male
# 4  After attacking and nearly killing his keeper,...
# 5  https://elephant-api.herokuapp.com/pictures/mi...
#
#                             5cf1d324458ad7dd80a510ce
# 0                                              Satao
# 1                           Tsavo East National Park
# 2                                            African
# 3                                               Male
# 4  One of Kenya's largest Africans, which had unu...
# 5  https://elephant-api.herokuapp.com/pictures/03...
#
# [6 rows x 47 columns]

# %%
elephants_df = elephants_df.T
elephants_df.columns = ['Name','Affiliation','Species','Sex','Note','Image']

# %%
elephants_df
# Out:
#                                              Name  \
# 5cf1d0db3cfbe0fcbb6c4c93               Abul-Abbas
# 5cf1d0db8c4845fb358b91d6                   Arjuna
# 5cf1d0dbcd5e98f2540c4d1c                 Balarama
# 5cf1d0dbe1b30267706da101            Black Diamond
# 5cf1d0db39d971a8ca87f8b1                    Batyr
# 5cf1d0db0574158b7a1c34f5                   Chunee
# 5cf1d0dbb3ae234b17062563  Chengalloor Ranganathan
# 5cf1d1adc46fd30ceb78ea71     The Cremona Elephant
# 5cf1d1ad31795d2421418824                    Hanno
# 5cf1d1adc6d79601c0fa1286                    Fanny
# 5cf1d1efb60e97c85ab4fc93                  Hansken
# 5cf1d1efcf45c435dbecb9b7                   Hattie
# 5cf1d1ef243ea2e6069a4a44                    Isilo
# 5cf1d1ef9bf1ce2d0844d8c6         John L. Sullivan
# 5cf1d1add907cd9f9df047b1                     Echo
# 5cf1d229450aa1d22eb8515c                   Kashin
# 5cf1d1ef814468cd1e877a7e                    Jumbo
# 5cf1d22923d1eb5854856999                  Kesavan
# 5cf1d22986fdc62d2cfcdc28                Kolakolli
# 5cf1d229b8bc2d4f70aa5b49             Lallah Rookh
# 5cf1d1adf325fd6ad3176d33                    Drona
# 5cf1d229c6e4d51fbb7523a7                 Lin Wang
# 5cf1d2291b62a78c9e9ad1f2                     Mary
# 5cf1d26746b81e3ade75512d                 Miss Jim
# 5cf1d26715dd3896b61a7ad6                    Motty
# 5cf1d267a82e8e66cce0fe95                     Mona
# 5cf1d2671f2c519d698bc455                    Packy
# 5cf1d26746e076b4331cc680                  Old Bet
# 5cf1d2c210735d003557514b                  Queenie
# 5cf1d2c28066a45f70fe1cad                 Raja Gaj
# 5cf1d2c2280da34cb73abce5                     Raja
# 5cf1d267441c5d5b2f308de0          Osama bin Laden
# 5cf1d2c2c9a0e486451f1d50                    Rajje
# 5cf1d2c2710b7e2f14158323                     Ruby
# 5cf1d2c2feb0255713c56412                    Rosie
# 5cf1d324f53859b0353d9339                     Salt
# 5cf1d2c29eb2ce805401789d                  Queenie
# 5cf1d32434d94cbfb43fd1c5                    Sauce
# 5cf1d324ebb6d39f48de496a  Thiruvambadi Sivasundar
# 5cf1d3240ed9228bbef619df                      Tai
# 5cf1d324eb450b52a52ba78d                 Suleiman
# 5cf1d374e96c3d81cb2d89dd                    Topsy
# 5cf1d32474fdff06d314da6a                    Surus
# 5cf1d37401c6112c72ee2489                    Tuffi
# 5cf1d374b45cf5da3bd9d810                     Tyke
# 5cf1d3741ca55f34f8561400                    Ziggy
# 5cf1d324458ad7dd80a510ce                    Satao
#
#                                                       Affiliation  \
# 5cf1d0db3cfbe0fcbb6c4c93                              Charlemagne
# 5cf1d0db8c4845fb358b91d6                                   Dasara
# 5cf1d0dbcd5e98f2540c4d1c                                   Dasara
# 5cf1d0dbe1b30267706da101                      Al G. Barnes Circus
# 5cf1d0db39d971a8ca87f8b1                            Karaganda Zoo
# 5cf1d0db0574158b7a1c34f5                          Exeter Exchange
# 5cf1d0dbb3ae234b17062563                       Arattupuzha Pooram
# 5cf1d1adc46fd30ceb78ea71          Holy Roman Emperor Frederick II
# 5cf1d1ad31795d2421418824                King Manuel I of Portugal
# 5cf1d1adc6d79601c0fa1286            Slater Park Zoo, Rhode Island
# 5cf1d1efb60e97c85ab4fc93               Frederik Hendrik of Orange
# 5cf1d1efcf45c435dbecb9b7                         Central Park Zoo
# 5cf1d1ef243ea2e6069a4a44                      Tembe Elephant Park
# 5cf1d1ef9bf1ce2d0844d8c6                    Adam Forepaugh Circus
# 5cf1d1add907cd9f9df047b1       Amboseli Elephant Research Project
# 5cf1d229450aa1d22eb8515c                             Auckland Zoo
# 5cf1d1ef814468cd1e877a7e                             P. T. Barnum
# 5cf1d22923d1eb5854856999          Guruvayur Temple, Kerala, India
# 5cf1d22986fdc62d2cfcdc28               Peppara Wildlife Sanctuary
# 5cf1d229b8bc2d4f70aa5b49                          Dan Rice Circus
# 5cf1d1adf325fd6ad3176d33                                   Dasara
# 5cf1d229c6e4d51fbb7523a7                               Taipei Zoo
# 5cf1d2291b62a78c9e9ad1f2         Sparks World Famous Shows Circus
# 5cf1d26746b81e3ade75512d                            St. Louis Zoo
# 5cf1d26715dd3896b61a7ad6                    Chester Zoo, Cheshire
# 5cf1d267a82e8e66cce0fe95                  Birmingham Zoo, Alabama
# 5cf1d2671f2c519d698bc455                               Oregon Zoo
# 5cf1d26746e076b4331cc680                         Hachaliah Bailey
# 5cf1d2c210735d003557514b                      Trefflich Pet Store
# 5cf1d2c28066a45f70fe1cad             Bardiya National Park, Nepal
# 5cf1d2c2280da34cb73abce5               Sri Dalada Maligawa, Kandy
# 5cf1d267441c5d5b2f308de0                             Assam, India
# 5cf1d2c2c9a0e486451f1d50                            William Pratt
# 5cf1d2c2710b7e2f14158323                              Phoenix Zoo
# 5cf1d2c2feb0255713c56412                     Miami Beach, Florida
# 5cf1d324f53859b0353d9339                  George William Lockhart
# 5cf1d2c29eb2ce805401789d                            Melbourne Zoo
# 5cf1d32434d94cbfb43fd1c5                  George William Lockhart
# 5cf1d324ebb6d39f48de496a  Thiruvambadi Sri Krishna Temple, Kerala
# 5cf1d3240ed9228bbef619df             Have Trunk Will Travel, Inc.
# 5cf1d324eb450b52a52ba78d                            Maximilian II
# 5cf1d374e96c3d81cb2d89dd                         Forepaugh Circus
# 5cf1d32474fdff06d314da6a                                 Hannibal
# 5cf1d37401c6112c72ee2489                      Cirque Alexis Gruss
# 5cf1d374b45cf5da3bd9d810   Circus International, Honolulu, Hawaii
# 5cf1d3741ca55f34f8561400                           Brookfield Zoo
# 5cf1d324458ad7dd80a510ce                 Tsavo East National Park
#
#                                         Species          Sex  \
# 5cf1d0db3cfbe0fcbb6c4c93                  Asian         Male
# 5cf1d0db8c4845fb358b91d6                  Asian         Male
# 5cf1d0dbcd5e98f2540c4d1c                  Asian         Male
# 5cf1d0dbe1b30267706da101                  Asian         Male
# 5cf1d0db39d971a8ca87f8b1                  Asian         Male
# 5cf1d0db0574158b7a1c34f5                  Asian         Male
# 5cf1d0dbb3ae234b17062563                  Asian         Male
# 5cf1d1adc46fd30ceb78ea71            Unavailable  Unavailable
# 5cf1d1ad31795d2421418824                  Asian         Male
# 5cf1d1adc6d79601c0fa1286                  Asian       Female
# 5cf1d1efb60e97c85ab4fc93                  Asian       Female
# 5cf1d1efcf45c435dbecb9b7                  Asian       Female
# 5cf1d1ef243ea2e6069a4a44                African         Male
# 5cf1d1ef9bf1ce2d0844d8c6                  Asian         Male
# 5cf1d1add907cd9f9df047b1  African Bush Elephant       Female
# 5cf1d229450aa1d22eb8515c                  Asian       Female
# 5cf1d1ef814468cd1e877a7e                African         Male
# 5cf1d22923d1eb5854856999                  Asian         Male
# 5cf1d22986fdc62d2cfcdc28                  Asian  Unavailable
# 5cf1d229b8bc2d4f70aa5b49                  Asian       Female
# 5cf1d1adf325fd6ad3176d33                  Asian         Male
# 5cf1d229c6e4d51fbb7523a7                  Asian         Male
# 5cf1d2291b62a78c9e9ad1f2                  Asian       Female
# 5cf1d26746b81e3ade75512d                  Asian       Female
# 5cf1d26715dd3896b61a7ad6        Hybrid Elephant         Male
# 5cf1d267a82e8e66cce0fe95                  Asian       Female
# 5cf1d2671f2c519d698bc455                  Asian         Male
# 5cf1d26746e076b4331cc680                  Asian       Female
# 5cf1d2c210735d003557514b                  Asian       Female
# 5cf1d2c28066a45f70fe1cad                  Asian         Male
# 5cf1d2c2280da34cb73abce5                  Asian         Male
# 5cf1d267441c5d5b2f308de0                  Asian         Male
# 5cf1d2c2c9a0e486451f1d50                  Asian       Female
# 5cf1d2c2710b7e2f14158323                  Asian       Female
# 5cf1d2c2feb0255713c56412                  Asian       Female
# 5cf1d324f53859b0353d9339                  Asian       Female
# 5cf1d2c29eb2ce805401789d                  Asian       Female
# 5cf1d32434d94cbfb43fd1c5                  Asian       Female
# 5cf1d324ebb6d39f48de496a                  Asian         Male
# 5cf1d3240ed9228bbef619df                  Asian       Female
# 5cf1d324eb450b52a52ba78d                African         Male
# 5cf1d374e96c3d81cb2d89dd                  Asian       Female
# 5cf1d32474fdff06d314da6a                  Asian  Unavailable
# 5cf1d37401c6112c72ee2489                  Asian       Female
# 5cf1d374b45cf5da3bd9d810                African       Female
# 5cf1d3741ca55f34f8561400                  Asian         Male
# 5cf1d324458ad7dd80a510ce                African         Male
#
#                                                                        Note  \
# 5cf1d0db3cfbe0fcbb6c4c93  An elephant given to Carolingian emperor Charl...
# 5cf1d0db8c4845fb358b91d6  A lead elephant of the world-famous Mysore Das...
# 5cf1d0dbcd5e98f2540c4d1c  A lead elephant of the world-famous Mysore Das...
# 5cf1d0dbe1b30267706da101  Believed to be the largest Indian elephant in ...
# 5cf1d0db39d971a8ca87f8b1  An elephant claimed to be able to use a large ...
# 5cf1d0db0574158b7a1c34f5  An elephant in the menagerie at Exeter Exchang...
# 5cf1d0dbb3ae234b17062563  Considered the tallest Asian thatever lived. H...
# 5cf1d1adc46fd30ceb78ea71  A gift presented to Holy Roman Emperor Frederi...
# 5cf1d1ad31795d2421418824  The pet white elephant given by King Manuel I ...
# 5cf1d1adc6d79601c0fa1286  A female elephant who spent the majority of he...
# 5cf1d1efb60e97c85ab4fc93  A female elephant that became famous in early ...
# 5cf1d1efcf45c435dbecb9b7  An elephant in New York City's Central Park Zo...
# 5cf1d1ef243ea2e6069a4a44  One of South Africa’s largest Africans and the...
# 5cf1d1ef9bf1ce2d0844d8c6      A boxing elephant in Adam Forepaugh's circus.
# 5cf1d1add907cd9f9df047b1                Most studied elephant in the world.
# 5cf1d229450aa1d22eb8515c  Famous for being sponsored by ASB Bank, and fe...
# 5cf1d1ef814468cd1e877a7e  A 19th-century male African bush elephant born...
# 5cf1d22923d1eb5854856999  Perhaps the most famous and celebrated temple ...
# 5cf1d22986fdc62d2cfcdc28  An Indian rogue elephant which gained consider...
# 5cf1d229b8bc2d4f70aa5b49  A female elephant known for her tightrope walk...
# 5cf1d1adf325fd6ad3176d33  The lead Dasara Elephants of the Jamboo Savari...
# 5cf1d229c6e4d51fbb7523a7  Served with the Chinese Expeditionary Force du...
# 5cf1d2291b62a78c9e9ad1f2  Also known as "Mighty Mary" and "Murderous Mar...
# 5cf1d26746b81e3ade75512d  A former circus elephant, bought for the zoo b...
# 5cf1d26715dd3896b61a7ad6      Only confirmed Asian/African hybrid elephant.
# 5cf1d267a82e8e66cce0fe95  Thought, at 60, to have been the oldest Asian ...
# 5cf1d2671f2c519d698bc455  First Asian born in the Western Hemisphere in ...
# 5cf1d26746e076b4331cc680  The first circus elephant and the second eleph...
# 5cf1d2c210735d003557514b  A captive female Asian which was noted in the ...
# 5cf1d2c28066a45f70fe1cad  Considered to be the world's largest Asian of ...
# 5cf1d2c2280da34cb73abce5  A Sri Lankan tusker elephant which participate...
# 5cf1d267441c5d5b2f308de0  Rogue elephant which killed at least 27 people...
# 5cf1d2c2c9a0e486451f1d50  A performing elephant that escaped into the st...
# 5cf1d2c2710b7e2f14158323  An elephant famous for creating paintings. The...
# 5cf1d2c2feb0255713c56412  An instrumental figure in the history of the U...
# 5cf1d324f53859b0353d9339  Salt and Sauce were once two of Britain's most...
# 5cf1d2c29eb2ce805401789d  Gave rides for children at Melbourne Zoo for 4...
# 5cf1d32434d94cbfb43fd1c5  Salt and Sauce were once two of Britain's most...
# 5cf1d324ebb6d39f48de496a  An Indian elephant purchased by businessman Su...
# 5cf1d3240ed9228bbef619df  Known for featuring in the films Larger than L...
# 5cf1d324eb450b52a52ba78d  Presented in 1551 to Maximilian II, the Holy R...
# 5cf1d374e96c3d81cb2d89dd  Killed a spectator who burned her trunk with a...
# 5cf1d32474fdff06d314da6a  Mentioned as the bravest of Hannibal's 37 war ...
# 5cf1d37401c6112c72ee2489  A female circus elephant that became famous in...
# 5cf1d374b45cf5da3bd9d810  A circus elephant who killed her trainer Allen...
# 5cf1d3741ca55f34f8561400  After attacking and nearly killing his keeper,...
# 5cf1d324458ad7dd80a510ce  One of Kenya's largest Africans, which had unu...
#
#                                                                       Image
# 5cf1d0db3cfbe0fcbb6c4c93  https://elephant-api.herokuapp.com/pictures/00...
# 5cf1d0db8c4845fb358b91d6  https://elephant-api.herokuapp.com/pictures/00...
# 5cf1d0dbcd5e98f2540c4d1c  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d0dbe1b30267706da101  https://elephant-api.herokuapp.com/pictures/00...
# 5cf1d0db39d971a8ca87f8b1  https://elephant-api.herokuapp.com/pictures/00...
# 5cf1d0db0574158b7a1c34f5  https://elephant-api.herokuapp.com/pictures/00...
# 5cf1d0dbb3ae234b17062563  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d1adc46fd30ceb78ea71  https://elephant-api.herokuapp.com/pictures/00...
# 5cf1d1ad31795d2421418824  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d1adc6d79601c0fa1286  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d1efb60e97c85ab4fc93  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d1efcf45c435dbecb9b7  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d1ef243ea2e6069a4a44  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d1ef9bf1ce2d0844d8c6  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d1add907cd9f9df047b1  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d229450aa1d22eb8515c  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d1ef814468cd1e877a7e  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d22923d1eb5854856999  https://elephant-api.herokuapp.com/pictures/01...
# 5cf1d22986fdc62d2cfcdc28  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d229b8bc2d4f70aa5b49  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d1adf325fd6ad3176d33  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d229c6e4d51fbb7523a7  https://elephant-api.herokuapp.com/pictures/02...
# 5cf1d2291b62a78c9e9ad1f2  https://elephant-api.herokuapp.com/pictures/02...
# 5cf1d26746b81e3ade75512d  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d26715dd3896b61a7ad6  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d267a82e8e66cce0fe95  https://elephant-api.herokuapp.com/pictures/02...
# 5cf1d2671f2c519d698bc455  https://elephant-api.herokuapp.com/pictures/02...
# 5cf1d26746e076b4331cc680  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d2c210735d003557514b  https://elephant-api.herokuapp.com/pictures/03...
# 5cf1d2c28066a45f70fe1cad  https://elephant-api.herokuapp.com/pictures/03...
# 5cf1d2c2280da34cb73abce5  https://elephant-api.herokuapp.com/pictures/03...
# 5cf1d267441c5d5b2f308de0  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d2c2c9a0e486451f1d50  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d2c2710b7e2f14158323  https://elephant-api.herokuapp.com/pictures/03...
# 5cf1d2c2feb0255713c56412  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d324f53859b0353d9339  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d2c29eb2ce805401789d  https://elephant-api.herokuapp.com/pictures/03...
# 5cf1d32434d94cbfb43fd1c5  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d324ebb6d39f48de496a  https://elephant-api.herokuapp.com/pictures/04...
# 5cf1d3240ed9228bbef619df  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d324eb450b52a52ba78d  https://elephant-api.herokuapp.com/pictures/04...
# 5cf1d374e96c3d81cb2d89dd  https://elephant-api.herokuapp.com/pictures/04...
# 5cf1d32474fdff06d314da6a  https://elephant-api.herokuapp.com/pictures/04...
# 5cf1d37401c6112c72ee2489  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d374b45cf5da3bd9d810  https://elephant-api.herokuapp.com/pictures/04...
# 5cf1d3741ca55f34f8561400  https://elephant-api.herokuapp.com/pictures/mi...
# 5cf1d324458ad7dd80a510ce  https://elephant-api.herokuapp.com/pictures/03...

# %% [markdown]
# ## What about pandas.read_json() method?

# %%
file = pd.read_json(url)

# %%
file
# Out:
#                          _id                              affiliation  \
# 0   5cf1d0db3cfbe0fcbb6c4c93                              Charlemagne
# 1   5cf1d0db8c4845fb358b91d6                                   Dasara
# 2   5cf1d0dbcd5e98f2540c4d1c                                   Dasara
# 3   5cf1d0dbe1b30267706da101                      Al G. Barnes Circus
# 4   5cf1d0db39d971a8ca87f8b1                            Karaganda Zoo
# 5   5cf1d0db0574158b7a1c34f5                          Exeter Exchange
# 6   5cf1d0dbb3ae234b17062563                       Arattupuzha Pooram
# 7   5cf1d1adc46fd30ceb78ea71          Holy Roman Emperor Frederick II
# 8   5cf1d1ad31795d2421418824                King Manuel I of Portugal
# 9   5cf1d1adc6d79601c0fa1286            Slater Park Zoo, Rhode Island
# 10  5cf1d1efb60e97c85ab4fc93               Frederik Hendrik of Orange
# 11  5cf1d1efcf45c435dbecb9b7                         Central Park Zoo
# 12  5cf1d1ef243ea2e6069a4a44                      Tembe Elephant Park
# 13  5cf1d1ef9bf1ce2d0844d8c6                    Adam Forepaugh Circus
# 14  5cf1d1add907cd9f9df047b1       Amboseli Elephant Research Project
# 15  5cf1d229450aa1d22eb8515c                             Auckland Zoo
# 16  5cf1d1ef814468cd1e877a7e                             P. T. Barnum
# 17  5cf1d22923d1eb5854856999          Guruvayur Temple, Kerala, India
# 18  5cf1d22986fdc62d2cfcdc28               Peppara Wildlife Sanctuary
# 19  5cf1d229b8bc2d4f70aa5b49                          Dan Rice Circus
# 20  5cf1d1adf325fd6ad3176d33                                   Dasara
# 21  5cf1d229c6e4d51fbb7523a7                               Taipei Zoo
# 22  5cf1d2291b62a78c9e9ad1f2         Sparks World Famous Shows Circus
# 23  5cf1d26746b81e3ade75512d                            St. Louis Zoo
# 24  5cf1d26715dd3896b61a7ad6                    Chester Zoo, Cheshire
# 25  5cf1d267a82e8e66cce0fe95                  Birmingham Zoo, Alabama
# 26  5cf1d2671f2c519d698bc455                               Oregon Zoo
# 27  5cf1d26746e076b4331cc680                         Hachaliah Bailey
# 28  5cf1d2c210735d003557514b                      Trefflich Pet Store
# 29  5cf1d2c28066a45f70fe1cad             Bardiya National Park, Nepal
# 30  5cf1d2c2280da34cb73abce5               Sri Dalada Maligawa, Kandy
# 31  5cf1d267441c5d5b2f308de0                             Assam, India
# 32  5cf1d2c2c9a0e486451f1d50                            William Pratt
# 33  5cf1d2c2710b7e2f14158323                              Phoenix Zoo
# 34  5cf1d2c2feb0255713c56412                     Miami Beach, Florida
# 35  5cf1d324f53859b0353d9339                  George William Lockhart
# 36  5cf1d2c29eb2ce805401789d                            Melbourne Zoo
# 37  5cf1d32434d94cbfb43fd1c5                  George William Lockhart
# 38  5cf1d324ebb6d39f48de496a  Thiruvambadi Sri Krishna Temple, Kerala
# 39  5cf1d3240ed9228bbef619df             Have Trunk Will Travel, Inc.
# 40  5cf1d324eb450b52a52ba78d                            Maximilian II
# 41  5cf1d374e96c3d81cb2d89dd                         Forepaugh Circus
# 42  5cf1d32474fdff06d314da6a                                 Hannibal
# 43  5cf1d37401c6112c72ee2489                      Cirque Alexis Gruss
# 44  5cf1d374b45cf5da3bd9d810   Circus International, Honolulu, Hawaii
# 45  5cf1d3741ca55f34f8561400                           Brookfield Zoo
# 46  5cf1d324458ad7dd80a510ce                 Tsavo East National Park
#
#             dob          dod fictional  \
# 0   Unavailable          810     false
# 1          1960            -     false
# 2          1958            -     false
# 3          1898         1929     false
# 4          1970         1993     false
# 5   Unavailable         1826     false
# 6   Unavailable         1927     false
# 7          12XX  Unavailable     false
# 8          1510         1516     false
# 9   Unavailable         2003     false
# 10         1630         1655     false
# 11  Unavailable         1922     false
# 12         1956         2014     false
# 13         1860         1932     false
# 14         1945         2009     false
# 15         1968         2009     false
# 16         1860         1885     false
# 17         1904         1976     false
# 18  Unavailable         2006     false
# 19  Unavailable         1860     false
# 20         1936         1998     false
# 21         1917         2003     false
# 22         1894         1916     false
# 23  Unavailable         1948     false
# 24         1978         1978     false
# 25         1951         2007     false
# 26         1962         2017     false
# 27  Unavailable         1816     false
# 28         1952         2011     false
# 29         1936         2007     false
# 30         1913         1988     false
# 31  Unavailable         2006     false
# 32         1951         1963     false
# 33         1973         1998     false
# 34  Unavailable         1938     false
# 35         1900         1952     false
# 36  Unavailable         1944     false
# 37         1900         1960     false
# 38         1972         2018     false
# 39         1968            -     false
# 40         1540         1553     false
# 41         1875         1903     false
# 42  Unavailable  Unavailable     false
# 43         1946         1989     false
# 44         1974         1994     false
# 45         1917         1975     false
# 46         1968         2014     false
#
#                                                 image  index  \
# 0   https://elephant-api.herokuapp.com/pictures/00...      1
# 1   https://elephant-api.herokuapp.com/pictures/00...      2
# 2   https://elephant-api.herokuapp.com/pictures/mi...      3
# 3   https://elephant-api.herokuapp.com/pictures/00...      5
# 4   https://elephant-api.herokuapp.com/pictures/00...      4
# 5   https://elephant-api.herokuapp.com/pictures/00...      7
# 6   https://elephant-api.herokuapp.com/pictures/mi...      6
# 7   https://elephant-api.herokuapp.com/pictures/00...      8
# 8   https://elephant-api.herokuapp.com/pictures/01...     12
# 9   https://elephant-api.herokuapp.com/pictures/01...     11
# 10  https://elephant-api.herokuapp.com/pictures/01...     13
# 11  https://elephant-api.herokuapp.com/pictures/01...     14
# 12  https://elephant-api.herokuapp.com/pictures/mi...     15
# 13  https://elephant-api.herokuapp.com/pictures/01...     16
# 14  https://elephant-api.herokuapp.com/pictures/01...     10
# 15  https://elephant-api.herokuapp.com/pictures/01...     18
# 16  https://elephant-api.herokuapp.com/pictures/01...     17
# 17  https://elephant-api.herokuapp.com/pictures/01...     19
# 18  https://elephant-api.herokuapp.com/pictures/mi...     20
# 19  https://elephant-api.herokuapp.com/pictures/mi...     21
# 20  https://elephant-api.herokuapp.com/pictures/mi...      9
# 21  https://elephant-api.herokuapp.com/pictures/02...     22
# 22  https://elephant-api.herokuapp.com/pictures/02...     23
# 23  https://elephant-api.herokuapp.com/pictures/mi...     24
# 24  https://elephant-api.herokuapp.com/pictures/mi...     26
# 25  https://elephant-api.herokuapp.com/pictures/02...     25
# 26  https://elephant-api.herokuapp.com/pictures/02...     29
# 27  https://elephant-api.herokuapp.com/pictures/mi...     27
# 28  https://elephant-api.herokuapp.com/pictures/03...     31
# 29  https://elephant-api.herokuapp.com/pictures/03...     33
# 30  https://elephant-api.herokuapp.com/pictures/03...     32
# 31  https://elephant-api.herokuapp.com/pictures/mi...     28
# 32  https://elephant-api.herokuapp.com/pictures/mi...     34
# 33  https://elephant-api.herokuapp.com/pictures/03...     36
# 34  https://elephant-api.herokuapp.com/pictures/mi...     35
# 35  https://elephant-api.herokuapp.com/pictures/mi...     37
# 36  https://elephant-api.herokuapp.com/pictures/03...     30
# 37  https://elephant-api.herokuapp.com/pictures/mi...     38
# 38  https://elephant-api.herokuapp.com/pictures/04...     42
# 39  https://elephant-api.herokuapp.com/pictures/mi...     43
# 40  https://elephant-api.herokuapp.com/pictures/04...     40
# 41  https://elephant-api.herokuapp.com/pictures/04...     44
# 42  https://elephant-api.herokuapp.com/pictures/04...     41
# 43  https://elephant-api.herokuapp.com/pictures/mi...     45
# 44  https://elephant-api.herokuapp.com/pictures/04...     46
# 45  https://elephant-api.herokuapp.com/pictures/mi...     47
# 46  https://elephant-api.herokuapp.com/pictures/03...     39
#
#                        name  \
# 0                Abul-Abbas
# 1                    Arjuna
# 2                  Balarama
# 3             Black Diamond
# 4                     Batyr
# 5                    Chunee
# 6   Chengalloor Ranganathan
# 7      The Cremona Elephant
# 8                     Hanno
# 9                     Fanny
# 10                  Hansken
# 11                   Hattie
# 12                    Isilo
# 13         John L. Sullivan
# 14                     Echo
# 15                   Kashin
# 16                    Jumbo
# 17                  Kesavan
# 18                Kolakolli
# 19             Lallah Rookh
# 20                    Drona
# 21                 Lin Wang
# 22                     Mary
# 23                 Miss Jim
# 24                    Motty
# 25                     Mona
# 26                    Packy
# 27                  Old Bet
# 28                  Queenie
# 29                 Raja Gaj
# 30                     Raja
# 31          Osama bin Laden
# 32                    Rajje
# 33                     Ruby
# 34                    Rosie
# 35                     Salt
# 36                  Queenie
# 37                    Sauce
# 38  Thiruvambadi Sivasundar
# 39                      Tai
# 40                 Suleiman
# 41                    Topsy
# 42                    Surus
# 43                    Tuffi
# 44                     Tyke
# 45                    Ziggy
# 46                    Satao
#
#                                                  note          sex  \
# 0   An elephant given to Carolingian emperor Charl...         Male
# 1   A lead elephant of the world-famous Mysore Das...         Male
# 2   A lead elephant of the world-famous Mysore Das...         Male
# 3   Believed to be the largest Indian elephant in ...         Male
# 4   An elephant claimed to be able to use a large ...         Male
# 5   An elephant in the menagerie at Exeter Exchang...         Male
# 6   Considered the tallest Asian thatever lived. H...         Male
# 7   A gift presented to Holy Roman Emperor Frederi...  Unavailable
# 8   The pet white elephant given by King Manuel I ...         Male
# 9   A female elephant who spent the majority of he...       Female
# 10  A female elephant that became famous in early ...       Female
# 11  An elephant in New York City's Central Park Zo...       Female
# 12  One of South Africa’s largest Africans and the...         Male
# 13      A boxing elephant in Adam Forepaugh's circus.         Male
# 14                Most studied elephant in the world.       Female
# 15  Famous for being sponsored by ASB Bank, and fe...       Female
# 16  A 19th-century male African bush elephant born...         Male
# 17  Perhaps the most famous and celebrated temple ...         Male
# 18  An Indian rogue elephant which gained consider...  Unavailable
# 19  A female elephant known for her tightrope walk...       Female
# 20  The lead Dasara Elephants of the Jamboo Savari...         Male
# 21  Served with the Chinese Expeditionary Force du...         Male
# 22  Also known as "Mighty Mary" and "Murderous Mar...       Female
# 23  A former circus elephant, bought for the zoo b...       Female
# 24      Only confirmed Asian/African hybrid elephant.         Male
# 25  Thought, at 60, to have been the oldest Asian ...       Female
# 26  First Asian born in the Western Hemisphere in ...         Male
# 27  The first circus elephant and the second eleph...       Female
# 28  A captive female Asian which was noted in the ...       Female
# 29  Considered to be the world's largest Asian of ...         Male
# 30  A Sri Lankan tusker elephant which participate...         Male
# 31  Rogue elephant which killed at least 27 people...         Male
# 32  A performing elephant that escaped into the st...       Female
# 33  An elephant famous for creating paintings. The...       Female
# 34  An instrumental figure in the history of the U...       Female
# 35  Salt and Sauce were once two of Britain's most...       Female
# 36  Gave rides for children at Melbourne Zoo for 4...       Female
# 37  Salt and Sauce were once two of Britain's most...       Female
# 38  An Indian elephant purchased by businessman Su...         Male
# 39  Known for featuring in the films Larger than L...       Female
# 40  Presented in 1551 to Maximilian II, the Holy R...         Male
# 41  Killed a spectator who burned her trunk with a...       Female
# 42  Mentioned as the bravest of Hannibal's 37 war ...  Unavailable
# 43  A female circus elephant that became famous in...       Female
# 44  A circus elephant who killed her trainer Allen...       Female
# 45  After attacking and nearly killing his keeper,...         Male
# 46  One of Kenya's largest Africans, which had unu...         Male
#
#                   species                                           wikilink
# 0                   Asian           https://en.wikipedia.org/wiki/Abul-Abbas
# 1                   Asian    https://en.wikipedia.org/wiki/Arjuna_(elephant)
# 2                   Asian  https://en.wikipedia.org/wiki/Balarama_(elephant)
# 3                   Asian  https://en.wikipedia.org/wiki/Black_Diamond_(e...
# 4                   Asian                https://en.wikipedia.org/wiki/Batyr
# 5                   Asian               https://en.wikipedia.org/wiki/Chunee
# 6                   Asian                                        Unavailable
# 7             Unavailable     https://en.wikipedia.org/wiki/Cremona_elephant
# 8                   Asian     https://en.wikipedia.org/wiki/Hanno_(elephant)
# 9                   Asian     https://en.wikipedia.org/wiki/Fanny_(elephant)
# 10                  Asian              https://en.wikipedia.org/wiki/Hansken
# 11                  Asian    https://en.wikipedia.org/wiki/Hattie_(elephant)
# 12                African     https://en.wikipedia.org/wiki/Isilo_(elephant)
# 13                  Asian  https://en.wikipedia.org/wiki/John_L._Sullivan...
# 14  African Bush Elephant      https://en.wikipedia.org/wiki/Echo_(elephant)
# 15                  Asian    https://en.wikipedia.org/wiki/Kashin_(elephant)
# 16                African                https://en.wikipedia.org/wiki/Jumbo
# 17                  Asian   https://en.wikipedia.org/wiki/Guruvayur_Keshavan
# 18                  Asian            https://en.wikipedia.org/wiki/Kolakolli
# 19                  Asian         https://en.wikipedia.org/wiki/Lallah_Rookh
# 20                  Asian     https://en.wikipedia.org/wiki/Drona_(elephant)
# 21                  Asian             https://en.wikipedia.org/wiki/Lin_Wang
# 22                  Asian      https://en.wikipedia.org/wiki/Mary_(elephant)
# 23                  Asian             https://en.wikipedia.org/wiki/Miss_Jim
# 24        Hybrid Elephant                https://en.wikipedia.org/wiki/Motty
# 25                  Asian      https://en.wikipedia.org/wiki/Mona_(elephant)
# 26                  Asian     https://en.wikipedia.org/wiki/Packy_(elephant)
# 27                  Asian              https://en.wikipedia.org/wiki/Old_Bet
# 28                  Asian  https://en.wikipedia.org/wiki/Queenie_(watersk...
# 29                  Asian             https://en.wikipedia.org/wiki/Raja_Gaj
# 30                  Asian      https://en.wikipedia.org/wiki/Raja_(elephant)
# 31                  Asian  https://en.wikipedia.org/wiki/Osama_bin_Laden_...
# 32                  Asian     https://en.wikipedia.org/wiki/Rajje_(elephant)
# 33                  Asian      https://en.wikipedia.org/wiki/Ruby_(elephant)
# 34                  Asian   https://en.wikipedia.org/wiki/Rosie_the_Elephant
# 35                  Asian       https://en.wikipedia.org/wiki/Salt_and_Sauce
# 36                  Asian  https://en.wikipedia.org/wiki/Queenie_(Melbour...
# 37                  Asian       https://en.wikipedia.org/wiki/Salt_and_Sauce
# 38                  Asian  https://en.wikipedia.org/wiki/Thiruvambadi_Siv...
# 39                  Asian       https://en.wikipedia.org/wiki/Tai_(elephant)
# 40                African  https://en.wikipedia.org/wiki/Suleiman_(elephant)
# 41                  Asian     https://en.wikipedia.org/wiki/Topsy_(elephant)
# 42                  Asian                https://en.wikipedia.org/wiki/Surus
# 43                  Asian                https://en.wikipedia.org/wiki/Tuffi
# 44                African      https://en.wikipedia.org/wiki/Tyke_(elephant)
# 45                  Asian     https://en.wikipedia.org/wiki/Ziggy_(elephant)
# 46                African     https://en.wikipedia.org/wiki/Satao_(elephant)

# %%
export_df = df.to_csv(r'C:\Users\jbenjamin\Desktop\FlatironDataScience\DataScienceCoach\elephants.csv')

# %%
export_df

# %%
new_df = pd.read_csv('../../../elephants.csv')

# %%
new_df
