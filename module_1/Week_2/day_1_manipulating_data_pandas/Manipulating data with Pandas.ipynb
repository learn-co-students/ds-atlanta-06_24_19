# %% [markdown]
# ## Module 1 - Manipulating data with Pandas¶

# %% [markdown]
# ### Pandas Part 2

# %% [markdown]
# ![austin](http://www.austintexas.gov/sites/default/files/aac_logo.jpg)

# %% [markdown]
# ### Scenario:

# %% [markdown]
# You have decided that you want to start your own animal shelter, but you want to get an idea of what that will entail and get more information about planning. In this lecture, we are continue to look at a real data set collected by Austin Animal Center over several years and use our pandas skills from the last lecture and learn some new ones in order to explore this data further.

# %% [markdown]
# #### Our goals today are to be able to:

# %% [markdown]
# Use the pandas library to:
#
# - Get summary info about a dataset and its variables.
#   Apply and use info, describe and dtypes.
#   Use mean, min, max, and value_counts.
# - Use apply and applymap to transform columns and create new values.
#
# - Explain lambda functions and use them to use an apply on a DataFrame.
#
# - Explain what a groupby object is and split a DataFrame using a groupby.

# %% [markdown]
# https://www.kaggle.com/ronitf/heart-disease-uci/version/1

# %% [markdown]
# - The dataset is most often used to practice classification algorithms.  We will return to classification in a few weeks, but for now we wish to use the dataset to practice some pandas methods.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('heart.csv')

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
print(df.shape)
# Out:
# (303, 14)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB
# None

# %% [markdown]
# - We can change the column type with the `astype` method. Let’s apply this method to the target feature and convert it to a bool:

# %%
df['target'] = df['target'].astype('bool')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1    True
# 1   0     2    True
# 2   0     2    True
# 3   0     2    True
# 4   0     2    True

# %% [markdown]
# - The `describe` method shows basic statistical characteristics of each numerical feature (int64 and float64 types): number of non-missing values, mean, standard deviation, range, median, 0.25 and 0.75 quartiles.

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal
# count  303.000000
# mean     2.313531
# std      0.612277
# min      0.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      3.000000

# %% [markdown]
# - In order to see statistics on non-numerical features, one has to explicitly indicate data types of interest in the include parameter.

# %%
df.describe(include=['object', 'bool'])
# Out:
#        target
# count     303
# unique      2
# top      True
# freq      165

# %% [markdown]
# - For categorical (type object) and boolean (type bool) features we can use the `value_counts` method. Let’s have a look at the distribution of target:
# - `value_counts` will also work on int and float types. Try it out!

# %%
df['target'].value_counts()
# Out:
# True     165
# False    138
# Name: target, dtype: int64

# %% [markdown]
# - To calculate fractions, pass `normalize=True` to the value_counts function.

# %%
df['target'].value_counts(normalize=True)
# Out:
# True     0.544554
# False    0.455446
# Name: target, dtype: float64

# %% [markdown]
# ### Sorting

# %% [markdown]
# - A DataFrame can be sorted by the value of one of its features (i.e columns). For example, we can sort by *chol* (use ascending=False to sort in descending order):

# %%
df.sort_values(by='chol',ascending=False).head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 85    67    0   2       115   564    0        0      160      0      1.6
# 28    65    0   2       140   417    1        0      157      0      0.8
# 246   56    0   0       134   409    0        0      150      1      1.9
# 220   63    0   0       150   407    0        0      154      0      4.0
# 96    62    0   0       140   394    0        0      157      0      1.2
#
#      slope  ca  thal  target
# 85       1   0     3    True
# 28       2   1     2    True
# 246      1   2     3   False
# 220      1   3     3   False
# 96       1   0     2    True

# %% [markdown]
# - We can also sort by multiple columns:

# %%
df.sort_values(by=['chol', 'age'],ascending=[True, False]).head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 111   57    1   2       150   126    1        1      173      0      0.2
# 301   57    1   0       130   131    0        1      115      1      1.2
# 53    44    0   2       108   141    0        1      175      0      0.6
# 151   71    0   0       112   149    0        1      125      0      1.6
# 267   49    1   2       118   149    0        0      126      0      0.8
#
#      slope  ca  thal  target
# 111      2   1     3    True
# 301      1   1     3   False
# 53       1   0     2    True
# 151      1   0     2    True
# 267      2   3     2   False

# %% [markdown]
# ### Finding Basic Statistics.

# %% [markdown]
# - We can find the mean of a specific column.

# %%
df['target'].mean()
# Out:
# 0.5445544554455446

# %% [markdown]
# - We can use boolean indexing to find the mean of the features for people with heart disease.

# %%
df[df['target'] == 1].mean()
# Out:
# age          52.496970
# sex           0.563636
# cp            1.375758
# trestbps    129.303030
# chol        242.230303
# fbs           0.139394
# restecg       0.593939
# thalach     158.466667
# exang         0.139394
# oldpeak       0.583030
# slope         1.593939
# ca            0.363636
# thal          2.121212
# target        1.000000
# dtype: float64

# %% [markdown]
# - We can do the above for a specific feature as well.

# %%
df[df['target'] == 1]['chol'].mean()
# Out:
# 242.23030303030302

# %% [markdown]
# - What is the max cholestrol with people with heart disease with age feature 40 or less?

# %%
df[(df['target'] == 1) & (df['age'] <= 40) & (df['age']  >= 30) ]['chol'].max()
# Out:
# 321

# %% [markdown]
# ### Changing Data

# %% [markdown]
# - https://chrisalbon.com/python/data_wrangling/pandas_apply_operations_to_dataframes/

# %% [markdown]
# - To apply functions to each column, use apply():

# %%
def square(x):
    return x**2

# %%
df.apply(square).head()
# Out:
#     age  sex  cp  trestbps    chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  3969    1   9     21025   54289    1        0    22500      0     5.29
# 1  1369    1   4     16900   62500    0        1    34969      0    12.25
# 2  1681    0   1     16900   41616    0        0    29584      0     1.96
# 3  3136    1   1     14400   55696    0        1    31684      0     0.64
# 4  3249    0   0     14400  125316    0        1    26569      1     0.36
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     4       1
# 2      4   0     4       1
# 3      4   0     4       1
# 4      4   0     4       1

# %% [markdown]
# - Apply `square` to a single column **cp**

# %%
# your code here
df['cp'].apply(square).head()
# Out:
# 0    9
# 1    4
# 2    1
# 3    1
# 4    0
# Name: cp, dtype: int64

# %% [markdown]
# - We can also use the apply function to subset on specific features.
# - Here we use a lambda function. More on them later!

# %%
df[df['sex'].apply(lambda gender: gender == 1)].head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
#
#    ca  thal  target
# 0   0     1    True
# 1   0     2    True
# 3   0     2    True
# 5   0     1    True
# 7   0     3    True

# %% [markdown]
# - The `applymap` method takes a function as input that it will then apply to every entry in the dataframe.

# %%
def plusone (x):
    return x+1

# %%
df.applymap(plusone).head()

# %% [markdown]
# - The `map` method can be used to replace values in a **column** by passing a dictionary of the form {old_value: new_value} as its argument.

# %%
dict_values = {1 : 'male', 0 : 'female'}
df['sex'] = df['sex'].map(dict_values)
df.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3       145   233    1        0      150      0      2.3
# 1   37    male   2       130   250    0        1      187      0      3.5
# 2   41  female   1       130   204    0        0      172      0      1.4
# 3   56    male   1       120   236    0        1      178      0      0.8
# 4   57  female   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1    True
# 1      0   0     2    True
# 2      2   0     2    True
# 3      2   0     2    True
# 4      2   0     2    True

# %% [markdown]
# #### Grouping

# %% [markdown]
# In general, grouping data in Pandas works as follows:

# %% [markdown]
# df.groupby(by=grouping_columns)[columns_to_show].function()

# %% [markdown]
# 1. First, the groupby method divides the grouping_columns by their values. They become a new index in the resulting dataframe.
# 2. Then, columns of interest are selected (columns_to_show). If columns_to_show is not included, all non groupby clauses will be included.
# 3. Finally, one or several functions are applied to the obtained groups per selected columns.

# %%
df = pd.read_csv('heart.csv')
df.groupby(['sex']).mean()
# Out:
#            age        cp    trestbps        chol      fbs   restecg  \
# sex
# 0    55.677083  1.041667  133.083333  261.302083  0.12500  0.572917
# 1    53.758454  0.932367  130.946860  239.289855  0.15942  0.507246
#
#         thalach     exang   oldpeak     slope        ca      thal    target
# sex
# 0    151.125000  0.229167  0.876042  1.427083  0.552083  2.125000  0.750000
# 1    148.961353  0.371981  1.115459  1.386473  0.811594  2.400966  0.449275

# %%
columns_to_show = ['sex', 'chol', 'trestbps']

df.groupby(['target'])[columns_to_show].describe(percentiles=[])
# Out:
#           sex                                      chol              \
#         count      mean       std  min  50%  max  count        mean
# target
# 0       138.0  0.826087  0.380416  0.0  1.0  1.0  138.0  251.086957
# 1       165.0  0.563636  0.497444  0.0  1.0  1.0  165.0  242.230303
#
#                                        trestbps                                \
#               std    min    50%    max    count        mean        std    min
# target
# 0       49.454614  131.0  249.0  409.0    138.0  134.398551  18.729944  100.0
# 1       53.552872  126.0  234.0  564.0    165.0  129.303030  16.169613   94.0
#
#
#           50%    max
# target
# 0       130.0  200.0
# 1       130.0  180.0

# %% [markdown]
# - Let’s do the same thing, but slightly differently by passing a list of functions to agg():

# %%
columns_to_show = ['sex', 'chol', 'trestbps']

df.groupby(['target'])[columns_to_show].agg([np.mean, np.std, np.min, 
                                            np.max])
# Out:
#              sex                            chol                       \
#             mean       std amin amax        mean        std amin amax
# target
# 0       0.826087  0.380416    0    1  251.086957  49.454614  131  409
# 1       0.563636  0.497444    0    1  242.230303  53.552872  126  564
#
#           trestbps
#               mean        std amin amax
# target
# 0       134.398551  18.729944  100  200
# 1       129.303030  16.169613   94  180

# %% [markdown]
# ### Class Fun!!

# %% [markdown]
# - Apply the new tools to the Animal Center data

# %%
import pandas as pd
shelter_data=pd.read_csv('https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD') 
shelter_data.head()
# Out:
#   Animal ID    Name                DateTime               MonthYear  \
# 0   A797930  Ranger  06/30/2019 07:24:00 PM  06/30/2019 07:24:00 PM
# 1   A794317   *Oreo  06/30/2019 07:14:00 PM  06/30/2019 07:14:00 PM
# 2   A797180     Leo  06/30/2019 07:04:00 PM  06/30/2019 07:04:00 PM
# 3   A792953   *Loaf  06/30/2019 07:04:00 PM  06/30/2019 07:04:00 PM
# 4   A795729   Laika  06/30/2019 07:00:00 PM  06/30/2019 07:00:00 PM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    06/19/2017     Adoption             NaN         Dog    Neutered Male
# 1    04/14/2019     Adoption             NaN         Cat    Spayed Female
# 2    06/10/2018     Adoption             NaN         Cat    Neutered Male
# 3    03/17/2019     Adoption             NaN         Cat    Neutered Male
# 4    05/23/2017     Adoption             NaN         Dog    Spayed Female
#
#   Age upon Outcome                     Breed        Color
# 0          2 years        Labrador Retriever    Chocolate
# 1         2 months    Domestic Shorthair Mix  Black/White
# 2           1 year  Domestic Medium Hair Mix  Brown Tabby
# 3         3 months    Domestic Shorthair Mix  Black/White
# 4          2 years           German Shepherd    Black/Tan

# %%
# Save a copy of manipulations to your local drive.
shelter_data.to_csv('Shelter_data')
